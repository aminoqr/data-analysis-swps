# %% [markdown]
# # Lab 8. Plot examples with `matplotlib`. Plot and pandas dataframe formatting and annotations.

# %% [markdown]
# ## 1. Radar Chart
#
# A radar chart (also known online as a polar chart, spider chart, or star chart) is a type of chart that is well-suited for comparing several characteristics across a small number of observations, typically two.
#
# > Documentation:
# > * https://matplotlib.org/stable/gallery/specialty_plots/radar_chart.html
# > * library with examples: https://matplotlib.org/stable/gallery/pie_and_polar_charts/index.html

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Listing 1**

# %%
# radar chart example

# data
labels = ['Strength', 'Stamina', 'Agility', 'Intelligence', 'Speed']
data = [17, 16, 12, 8, 13]

# angles - number of axis on radar plot - depends on number of features (labels)
# linspace - creates linear space for a given range and number of values
# here - we divide a circle (360 degrees = 2 * np.pi) into 5 equal parts
angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))

# now we fill pieces witj a color ang set a transparency equal to 33%
ax.fill(angles, data, color='red', alpha=0.33)
# we can draw lines at the edges of a space (optional)
# ax.plot(angles, data, color='red', linewidth=1)

# Set the axes so that they start at “12 o'clock”
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)

# setting labels on plot for each axis to be equal to our label names
ax.set_thetagrids(np.degrees(angles), labels);

# %% [markdown]
# **Listing 2**

# %%
# example of multiple series (layers) on one plot
# data
labels = ['Strength', 'Stamina', 'Agility', 'Intelligence', 'Speed']
data = [[17, 16, 12, 8, 13], [12, 11, 17, 14, 11]]

angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))

ax.fill(angles, data[0], color='red', alpha=0.25, label='Mario')
ax.fill(angles, data[1], color='blue', alpha=0.25, label='Luigi')
# ax.plot(angles, data, color='red', linewidth=1)

ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)

ax.set_thetagrids(np.degrees(angles), labels)
plt.legend();

# %% [markdown]
# ## 2. Animated plots (another example)

# %% [markdown]
# **Listing 3**

# %%
# Example of a chart animation from the official documentation
# https://matplotlib.org/stable/gallery/animation/simple_anim.html#sphx-glr-gallery-animation-simple-anim-py
# For the animation to work, run the script from the terminal (you can also start a terminal session via Jupyter Lab)
# the finished script is located in the test.py file

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig, ax = plt.subplots()

x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))


def animate(i):
    line.set_ydata(np.sin(x + i / 50))  # update the data.
    return line,


ani = animation.FuncAnimation(
    fig, animate, interval=20, blit=True, save_count=50)

# To save the animation, use e.g.
#
# ani.save("movie.mp4")
#
# or
#
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)

plt.show()
# Out:
# /tmp/ipykernel_13864/1368681049.py:34: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## 3. Plot annotations
#
# In addition to raw data and basic information within the chart area—such as legends and axis labels—we can also “embellish” the chart with additional elements like lines, symbols, or text placed at specific locations within the chart. The placement of these elements is usually relative to values on both axes, but can also be specified as an absolute value, e.g., in the form of coordinates expressed in pixels.
#
# **Example 1 - Vertical Line**
#
# A vertical line at the position specified by the value on the `x` axis.
# Documentation:
# * https://matplotlib.org/3.10.1/api/_as_gen/matplotlib.pyplot.axline.html
# * https://matplotlib.org/3.10.1/api/_as_gen/matplotlib.pyplot.axvline.html
# * https://matplotlib.org/3.10.1/api/_as_gen/matplotlib.pyplot.axhline.html

# %% [markdown]
# **Listing 4**

# %%
# data
values = np.random.randn(100).cumsum()

# vertical line on the canvas - full length
# first argument of this function is index of the data element where the line
# should be created on x axis
plt.axvline(np.argmax(values), color='r')
plt.plot(values);

# %% [markdown]
# **Example 2 - Graphic Objects**
#
# These are typically symbols such as arrows, simple geometric shapes, and text.
#
# > Documentation:
# > * https://matplotlib.org/3.10.1/tutorials/text/annotations.html#sphx-glr-tutorials-text-annotations-py
# > * https://matplotlib.org/stable/gallery/text_labels_and_annotations/annotation_demo.html
# > * https://matplotlib.org/stable/gallery/index.html#text-labels-and-annotations

# %%
# We store the plot and axis objects in variables
fig, ax = plt.subplots()

# The xy parameter specifies the x1, y1 coordinates—here, the point where the arrowhead points
# The xytext parameter specifies the x2, y2 coordinates—the start of the arrow and the text position (optional)
# The xycoords and textcoords parameters indicate that the coordinates will be passed as values
# from the data (i.e., 10 represents the point with a value of 10 on the axis, not the 10th element)
ax.annotate("max",
            xy=(np.argmax(values), np.max(values)), xycoords='data',
            xytext=(len(values)/4, np.mean(values)), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            );
plt.plot(values);

# %% [markdown]
# Rerun the code from listing 3 and 4 - the arrow is dinamically pointing to the maximum value on the plot.

# %% [markdown]
# **Example 3 - Filling an area**
#
# > Documentation:
# > * https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.fill_between.html#matplotlib.pyplot.fill_between

# %%
# x and y1 contain the coordinates that will be filled with the specified color
# both vectors must have the same number of elements
# here we retrieve the first 30 values from the entire set
plt.fill_between(
        x = list(range(30)),
        y1 = values[:30],
        color= "g",
        alpha= 0.2);

# %%
# Here we color the data for the entire chart, but filter it (where) to include only the values
# from the vector that meet a given condition (boolean array)
plt.fill_between(
        x = list(range(len(values))),
        y1 = values,
        where = (values > 0),
        color= "g",
        alpha= 0.2);

# %% [markdown]
# ## 4. Formatting pandas DataFrames (in Jupyter Notebook)
# In addition to being able to display a DataFrame as a clearly formatted HTML table, you can also define your own styles and formatting conditions for this output.
#
# > Documentation:
#
# > * https://pandas.pydata.org/docs/user_guide/style.html
# > * https://www.analyticsvidhya.com/blog/2021/06/style-your-pandas-dataframe-and-make-it-stunning/
# > * https://coderzcolumn.com/tutorials/python/simple-guide-to-style-display-of-pandas-dataframes

# %%
import pandas as pd

df = pd.read_csv('data/pkn.txt')
df['<DATE>'] = pd.to_datetime(df['<DATE>'], format='%Y%m%d')

# A minor transformation of the raw data; column names in the format <NAME> caused
# incorrect behavior with formatting-related options
df.drop(columns=['<PER>', '<TIME>', '<OPENINT>'], inplace=True)
df.columns = [column.replace('<','').replace('>','') for column in df.columns]
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5583 entries, 0 to 5582
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TICKER  5583 non-null   str
#  1   DATE    5583 non-null   datetime64[us]
#  2   OPEN    5583 non-null   float64
#  3   HIGH    5583 non-null   float64
#  4   LOW     5583 non-null   float64
#  5   CLOSE   5583 non-null   float64
#  6   VOL     5583 non-null   int64
# dtypes: datetime64[us](1), float64(4), int64(1), str(1)
# memory usage: 305.4 KB

# %%
# for this example we will select only a small piece of data
df10 = df[:10]
df10.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TICKER  10 non-null     str
#  1   DATE    10 non-null     datetime64[us]
#  2   OPEN    10 non-null     float64
#  3   HIGH    10 non-null     float64
#  4   LOW     10 non-null     float64
#  5   CLOSE   10 non-null     float64
#  6   VOL     10 non-null     int64
# dtypes: datetime64[us](1), float64(4), int64(1), str(1)
# memory usage: 692.0 bytes

# %%
df10
# Out:
#   TICKER       DATE    OPEN    HIGH     LOW   CLOSE       VOL
# 0    PKN 1999-11-26  15.268  15.403  14.715  15.194  15857000
# 1    PKN 1999-11-29  15.124  15.194  14.852  14.923   5499196
# 2    PKN 1999-11-30  15.060  15.330  15.060  15.194   3287087
# 3    PKN 1999-12-01  15.330  15.674  15.194  15.674   3077747
# 4    PKN 1999-12-02  15.818  16.297  15.745  15.954   3304014
# 5    PKN 1999-12-03  15.954  16.225  15.818  16.159   2357914
# 6    PKN 1999-12-06  16.297  16.847  16.297  16.776   3005048
# 7    PKN 1999-12-07  16.711  16.776  16.503  16.503   2426246
# 8    PKN 1999-12-08  16.503  16.911  16.503  16.639   3807338
# 9    PKN 1999-12-09  16.639  16.639  16.225  16.503   2513405

# %% [markdown]
# **Example 1** - formatting output numbers.

# %%
# Example of formatting displayed values (output only)
df10.style.format(precision=2
                  ,thousands=" "
                  ,formatter={'OPEN': lambda x: f"{x:,.2f} zł"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_63791">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63791_level0_col0" class="col_heading level0 col0" >TICKER</th>
#       <th id="T_63791_level0_col1" class="col_heading level0 col1" >DATE</th>
#       <th id="T_63791_level0_col2" class="col_heading level0 col2" >OPEN</th>
#       <th id="T_63791_level0_col3" class="col_heading level0 col3" >HIGH</th>
#       <th id="T_63791_level0_col4" class="col_heading level0 col4" >LOW</th>
#       <th id="T_63791_level0_col5" class="col_heading level0 col5" >CLOSE</th>
#       <th id="T_63791_level0_col6" class="col_heading level0 col6" >VOL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63791_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63791_row0_col0" class="data row0 col0" >PKN</td>
#       <td id="T_63791_row0_col1" class="data row0 col1" >1999-11-26 00:00:00</td>
#       <td id="T_63791_row0_col2" class="data row0 col2" >15.27 zł</td>
#       <td id="T_63791_row0_col3" class="data row0 col3" >15.40</td>
#       <td id="T_63791_row0_col4" class="data row0 col4" >14.71</td>
#       <td id="T_63791_row0_col5" class="data row0 col5" >15.19</td>
#       <td id="T_63791_row0_col6" class="data row0 col6" >15 857 000</td>
#     </tr>
#     <tr>
#       <th id="T_63791_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_63791_row1_col0" class="data row1 col0" >PKN</td>
#       <td id="T_63791_row1_col1" class="data row1 col1" >1999-11-29 00:00:00</td>
#       <td id="T_63791_row1_col2" class="data row1 col2" >15.12 zł</td>
#       <td id="T_63791_row1_col3" class="data row1 col3" >15.19</td>
#       <td id="T_63791_row1_col4" class="data row1 col4" >14.85</td>
#       <td id="T_63791_row1_col5" class="data row1 col5" >14.92</td>
#       <td id="T_63791_row1_col6" class="data row1 col6" >5 499 196</td>
#     </tr>
#     <tr>
#       <th id="T_63791_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_63791_row2_col0" class="data row2 col0" >PKN</td>
#       <td id="T_63791_row2_col1" class="data row2 col1" >1999-11-30 00:00:00</td>
#       <td id="T_63791_row2_col2" class="data row2 col2" >15.06 zł</td>
#       <td id="T_63791_row2_col3" class="data row2 col3" >15.33</td>
#       <td id="T_63791_row2_col4" class="data row2 col4" >15.06</td>
#       <td id="T_63791_row2_col5" class="data row2 col5" >15.19</td>
#       <td id="T_63791_row2_col6" class="data row2 col6" >3 287 087</td>
#     </tr>
#     <tr>
#       <th id="T_63791_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_63791_row3_col0" class="data row3 col0" >PKN</td>
#       <td id="T_63791_row3_col1" class="data row3 col1" >1999-12-01 00:00:00</td>
#       <td id="T_63791_row3_col2" class="data row3 col2" >15.33 zł</td>
#       <td id="T_63791_row3_col3" class="data row3 col3" >15.67</td>
#       <td id="T_63791_row3_col4" class="data row3 col4" >15.19</td>
#       <td id="T_63791_row3_col5" class="data row3 col5" >15.67</td>
#       <td id="T_63791_row3_col6" class="data row3 col6" >3 077 747</td>
#     </tr>
#     <tr>
#       <th id="T_63791_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_63791_row4_col0" class="data row4 col0" >PKN</td>
#       <td id="T_63791_row4_col1" class="data row4 col1" >1999-12-02 00:00:00</td>
#       <td id="T_63791_row4_col2" class="data row4 col2" >15.82 zł</td>
#       <td id="T_63791_row4_col3" class="data row4 col3" >16.30</td>
#       <td id="T_63791_row4_col4" class="data row4 col4" >15.74</td>
#       <td id="T_63791_row4_col5" class="data row4 col5" >15.95</td>
#       <td id="T_63791_row4_col6" class="data row4 col6" >3 304 014</td>
#     </tr>
#     <tr>
#       <th id="T_63791_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_63791_row5_col0" class="data row5 col0" >PKN</td>
#       <td id="T_63791_row5_col1" class="data row5 col1" >1999-12-03 00:00:00</td>
#       <td id="T_63791_row5_col2" class="data row5 col2" >15.95 zł</td>
#       <td id="T_63791_row5_col3" class="data row5 col3" >16.23</td>
#       <td id="T_63791_row5_col4" class="data row5 col4" >15.82</td>
#       <td id="T_63791_row5_col5" class="data row5 col5" >16.16</td>
#       <td id="T_63791_row5_col6" class="data row5 col6" >2 357 914</td>
#     </tr>
#     <tr>
#       <th id="T_63791_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_63791_row6_col0" class="data row6 col0" >PKN</td>
#       <td id="T_63791_row6_col1" class="data row6 col1" >1999-12-06 00:00:00</td>
#       <td id="T_63791_row6_col2" class="data row6 col2" >16.30 zł</td>
#       <td id="T_63791_row6_col3" class="data row6 col3" >16.85</td>
#       <td id="T_63791_row6_col4" class="data row6 col4" >16.30</td>
#       <td id="T_63791_row6_col5" class="data row6 col5" >16.78</td>
#       <td id="T_63791_row6_col6" class="data row6 col6" >3 005 048</td>
#     </tr>
#     <tr>
#       <th id="T_63791_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_63791_row7_col0" class="data row7 col0" >PKN</td>
#       <td id="T_63791_row7_col1" class="data row7 col1" >1999-12-07 00:00:00</td>
#       <td id="T_63791_row7_col2" class="data row7 col2" >16.71 zł</td>
#       <td id="T_63791_row7_col3" class="data row7 col3" >16.78</td>
#       <td id="T_63791_row7_col4" class="data row7 col4" >16.50</td>
#       <td id="T_63791_row7_col5" class="data row7 col5" >16.50</td>
#       <td id="T_63791_row7_col6" class="data row7 col6" >2 426 246</td>
#     </tr>
#     <tr>
#       <th id="T_63791_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_63791_row8_col0" class="data row8 col0" >PKN</td>
#       <td id="T_63791_row8_col1" class="data row8 col1" >1999-12-08 00:00:00</td>
#       <td id="T_63791_row8_col2" class="data row8 col2" >16.50 zł</td>
#       <td id="T_63791_row8_col3" class="data row8 col3" >16.91</td>
#       <td id="T_63791_row8_col4" class="data row8 col4" >16.50</td>
#       <td id="T_63791_row8_col5" class="data row8 col5" >16.64</td>
#       <td id="T_63791_row8_col6" class="data row8 col6" >3 807 338</td>
#     </tr>
#     <tr>
#       <th id="T_63791_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_63791_row9_col0" class="data row9 col0" >PKN</td>
#       <td id="T_63791_row9_col1" class="data row9 col1" >1999-12-09 00:00:00</td>
#       <td id="T_63791_row9_col2" class="data row9 col2" >16.64 zł</td>
#       <td id="T_63791_row9_col3" class="data row9 col3" >16.64</td>
#       <td id="T_63791_row9_col4" class="data row9 col4" >16.23</td>
#       <td id="T_63791_row9_col5" class="data row9 col5" >16.50</td>
#       <td id="T_63791_row9_col6" class="data row9 col6" >2 513 405</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Example 2** - conditional formatting.

# %%
# Formatting maximum values in columns + previous format
# first parameter of the highlight_max function is a subset of column names to format
df10.style.highlight_max(df10.columns[1:], color='green') \
    .format(precision=2
                  ,thousands=" "
                  ,formatter={'OPEN': lambda x: f"{x:,.2f} zł"})
# Out:
# <style type="text/css">
# #T_e0e24_row0_col6, #T_e0e24_row6_col5, #T_e0e24_row7_col2, #T_e0e24_row7_col4, #T_e0e24_row8_col3, #T_e0e24_row8_col4, #T_e0e24_row9_col1 {
#   background-color: green;
# }
# </style>
# <table id="T_e0e24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0e24_level0_col0" class="col_heading level0 col0" >TICKER</th>
#       <th id="T_e0e24_level0_col1" class="col_heading level0 col1" >DATE</th>
#       <th id="T_e0e24_level0_col2" class="col_heading level0 col2" >OPEN</th>
#       <th id="T_e0e24_level0_col3" class="col_heading level0 col3" >HIGH</th>
#       <th id="T_e0e24_level0_col4" class="col_heading level0 col4" >LOW</th>
#       <th id="T_e0e24_level0_col5" class="col_heading level0 col5" >CLOSE</th>
#       <th id="T_e0e24_level0_col6" class="col_heading level0 col6" >VOL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0e24_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0e24_row0_col0" class="data row0 col0" >PKN</td>
#       <td id="T_e0e24_row0_col1" class="data row0 col1" >1999-11-26 00:00:00</td>
#       <td id="T_e0e24_row0_col2" class="data row0 col2" >15.27 zł</td>
#       <td id="T_e0e24_row0_col3" class="data row0 col3" >15.40</td>
#       <td id="T_e0e24_row0_col4" class="data row0 col4" >14.71</td>
#       <td id="T_e0e24_row0_col5" class="data row0 col5" >15.19</td>
#       <td id="T_e0e24_row0_col6" class="data row0 col6" >15 857 000</td>
#     </tr>
#     <tr>
#       <th id="T_e0e24_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e0e24_row1_col0" class="data row1 col0" >PKN</td>
#       <td id="T_e0e24_row1_col1" class="data row1 col1" >1999-11-29 00:00:00</td>
#       <td id="T_e0e24_row1_col2" class="data row1 col2" >15.12 zł</td>
#       <td id="T_e0e24_row1_col3" class="data row1 col3" >15.19</td>
#       <td id="T_e0e24_row1_col4" class="data row1 col4" >14.85</td>
#       <td id="T_e0e24_row1_col5" class="data row1 col5" >14.92</td>
#       <td id="T_e0e24_row1_col6" class="data row1 col6" >5 499 196</td>
#     </tr>
#     <tr>
#       <th id="T_e0e24_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e0e24_row2_col0" class="data row2 col0" >PKN</td>
#       <td id="T_e0e24_row2_col1" class="data row2 col1" >1999-11-30 00:00:00</td>
#       <td id="T_e0e24_row2_col2" class="data row2 col2" >15.06 zł</td>
#       <td id="T_e0e24_row2_col3" class="data row2 col3" >15.33</td>
#       <td id="T_e0e24_row2_col4" class="data row2 col4" >15.06</td>
#       <td id="T_e0e24_row2_col5" class="data row2 col5" >15.19</td>
#       <td id="T_e0e24_row2_col6" class="data row2 col6" >3 287 087</td>
#     </tr>
#     <tr>
#       <th id="T_e0e24_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e0e24_row3_col0" class="data row3 col0" >PKN</td>
#       <td id="T_e0e24_row3_col1" class="data row3 col1" >1999-12-01 00:00:00</td>
#       <td id="T_e0e24_row3_col2" class="data row3 col2" >15.33 zł</td>
#       <td id="T_e0e24_row3_col3" class="data row3 col3" >15.67</td>
#       <td id="T_e0e24_row3_col4" class="data row3 col4" >15.19</td>
#       <td id="T_e0e24_row3_col5" class="data row3 col5" >15.67</td>
#       <td id="T_e0e24_row3_col6" class="data row3 col6" >3 077 747</td>
#     </tr>
#     <tr>
#       <th id="T_e0e24_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e0e24_row4_col0" class="data row4 col0" >PKN</td>
#       <td id="T_e0e24_row4_col1" class="data row4 col1" >1999-12-02 00:00:00</td>
#       <td id="T_e0e24_row4_col2" class="data row4 col2" >15.82 zł</td>
#       <td id="T_e0e24_row4_col3" class="data row4 col3" >16.30</td>
#       <td id="T_e0e24_row4_col4" class="data row4 col4" >15.74</td>
#       <td id="T_e0e24_row4_col5" class="data row4 col5" >15.95</td>
#       <td id="T_e0e24_row4_col6" class="data row4 col6" >3 304 014</td>
#     </tr>
#     <tr>
#       <th id="T_e0e24_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e0e24_row5_col0" class="data row5 col0" >PKN</td>
#       <td id="T_e0e24_row5_col1" class="data row5 col1" >1999-12-03 00:00:00</td>
#       <td id="T_e0e24_row5_col2" class="data row5 col2" >15.95 zł</td>
#       <td id="T_e0e24_row5_col3" class="data row5 col3" >16.23</td>
#       <td id="T_e0e24_row5_col4" class="data row5 col4" >15.82</td>
#       <td id="T_e0e24_row5_col5" class="data row5 col5" >16.16</td>
#       <td id="T_e0e24_row5_col6" class="data row5 col6" >2 357 914</td>
#     </tr>
#     <tr>
#       <th id="T_e0e24_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e0e24_row6_col0" class="data row6 col0" >PKN</td>
#       <td id="T_e0e24_row6_col1" class="data row6 col1" >1999-12-06 00:00:00</td>
#       <td id="T_e0e24_row6_col2" class="data row6 col2" >16.30 zł</td>
#       <td id="T_e0e24_row6_col3" class="data row6 col3" >16.85</td>
#       <td id="T_e0e24_row6_col4" class="data row6 col4" >16.30</td>
#       <td id="T_e0e24_row6_col5" class="data row6 col5" >16.78</td>
#       <td id="T_e0e24_row6_col6" class="data row6 col6" >3 005 048</td>
#     </tr>
#     <tr>
#       <th id="T_e0e24_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e0e24_row7_col0" class="data row7 col0" >PKN</td>
#       <td id="T_e0e24_row7_col1" class="data row7 col1" >1999-12-07 00:00:00</td>
#       <td id="T_e0e24_row7_col2" class="data row7 col2" >16.71 zł</td>
#       <td id="T_e0e24_row7_col3" class="data row7 col3" >16.78</td>
#       <td id="T_e0e24_row7_col4" class="data row7 col4" >16.50</td>
#       <td id="T_e0e24_row7_col5" class="data row7 col5" >16.50</td>
#       <td id="T_e0e24_row7_col6" class="data row7 col6" >2 426 246</td>
#     </tr>
#     <tr>
#       <th id="T_e0e24_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e0e24_row8_col0" class="data row8 col0" >PKN</td>
#       <td id="T_e0e24_row8_col1" class="data row8 col1" >1999-12-08 00:00:00</td>
#       <td id="T_e0e24_row8_col2" class="data row8 col2" >16.50 zł</td>
#       <td id="T_e0e24_row8_col3" class="data row8 col3" >16.91</td>
#       <td id="T_e0e24_row8_col4" class="data row8 col4" >16.50</td>
#       <td id="T_e0e24_row8_col5" class="data row8 col5" >16.64</td>
#       <td id="T_e0e24_row8_col6" class="data row8 col6" >3 807 338</td>
#     </tr>
#     <tr>
#       <th id="T_e0e24_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e0e24_row9_col0" class="data row9 col0" >PKN</td>
#       <td id="T_e0e24_row9_col1" class="data row9 col1" >1999-12-09 00:00:00</td>
#       <td id="T_e0e24_row9_col2" class="data row9 col2" >16.64 zł</td>
#       <td id="T_e0e24_row9_col3" class="data row9 col3" >16.64</td>
#       <td id="T_e0e24_row9_col4" class="data row9 col4" >16.23</td>
#       <td id="T_e0e24_row9_col5" class="data row9 col5" >16.50</td>
#       <td id="T_e0e24_row9_col6" class="data row9 col6" >2 513 405</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Example 3** - setting subsets for both formatters

# %%
# We probably aren't interested in the maximum values in the column containing the asset name and date
# We can specify which columns (or, more precisely, a subset of them) should be formatted
# more on using the format() function: https://pandas.pydata.org/docs/reference/api/pandas.io.formats.style.Styler.format.html
slice_ = ['OPEN','CLOSE','LOW','HIGH','VOL']
df10.style.highlight_max(color='green', subset=slice_) \
    .format(precision=2
                  ,thousands=" "
                  ,formatter=lambda x: f"{x:,.2f} zł"
                  ,subset=['OPEN','CLOSE','LOW','HIGH'])
# Out:
# <style type="text/css">
# #T_d4025_row0_col6, #T_d4025_row6_col5, #T_d4025_row7_col2, #T_d4025_row7_col4, #T_d4025_row8_col3, #T_d4025_row8_col4 {
#   background-color: green;
# }
# </style>
# <table id="T_d4025">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4025_level0_col0" class="col_heading level0 col0" >TICKER</th>
#       <th id="T_d4025_level0_col1" class="col_heading level0 col1" >DATE</th>
#       <th id="T_d4025_level0_col2" class="col_heading level0 col2" >OPEN</th>
#       <th id="T_d4025_level0_col3" class="col_heading level0 col3" >HIGH</th>
#       <th id="T_d4025_level0_col4" class="col_heading level0 col4" >LOW</th>
#       <th id="T_d4025_level0_col5" class="col_heading level0 col5" >CLOSE</th>
#       <th id="T_d4025_level0_col6" class="col_heading level0 col6" >VOL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4025_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4025_row0_col0" class="data row0 col0" >PKN</td>
#       <td id="T_d4025_row0_col1" class="data row0 col1" >1999-11-26 00:00:00</td>
#       <td id="T_d4025_row0_col2" class="data row0 col2" >15.27 zł</td>
#       <td id="T_d4025_row0_col3" class="data row0 col3" >15.40 zł</td>
#       <td id="T_d4025_row0_col4" class="data row0 col4" >14.71 zł</td>
#       <td id="T_d4025_row0_col5" class="data row0 col5" >15.19 zł</td>
#       <td id="T_d4025_row0_col6" class="data row0 col6" >15857000</td>
#     </tr>
#     <tr>
#       <th id="T_d4025_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d4025_row1_col0" class="data row1 col0" >PKN</td>
#       <td id="T_d4025_row1_col1" class="data row1 col1" >1999-11-29 00:00:00</td>
#       <td id="T_d4025_row1_col2" class="data row1 col2" >15.12 zł</td>
#       <td id="T_d4025_row1_col3" class="data row1 col3" >15.19 zł</td>
#       <td id="T_d4025_row1_col4" class="data row1 col4" >14.85 zł</td>
#       <td id="T_d4025_row1_col5" class="data row1 col5" >14.92 zł</td>
#       <td id="T_d4025_row1_col6" class="data row1 col6" >5499196</td>
#     </tr>
#     <tr>
#       <th id="T_d4025_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d4025_row2_col0" class="data row2 col0" >PKN</td>
#       <td id="T_d4025_row2_col1" class="data row2 col1" >1999-11-30 00:00:00</td>
#       <td id="T_d4025_row2_col2" class="data row2 col2" >15.06 zł</td>
#       <td id="T_d4025_row2_col3" class="data row2 col3" >15.33 zł</td>
#       <td id="T_d4025_row2_col4" class="data row2 col4" >15.06 zł</td>
#       <td id="T_d4025_row2_col5" class="data row2 col5" >15.19 zł</td>
#       <td id="T_d4025_row2_col6" class="data row2 col6" >3287087</td>
#     </tr>
#     <tr>
#       <th id="T_d4025_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d4025_row3_col0" class="data row3 col0" >PKN</td>
#       <td id="T_d4025_row3_col1" class="data row3 col1" >1999-12-01 00:00:00</td>
#       <td id="T_d4025_row3_col2" class="data row3 col2" >15.33 zł</td>
#       <td id="T_d4025_row3_col3" class="data row3 col3" >15.67 zł</td>
#       <td id="T_d4025_row3_col4" class="data row3 col4" >15.19 zł</td>
#       <td id="T_d4025_row3_col5" class="data row3 col5" >15.67 zł</td>
#       <td id="T_d4025_row3_col6" class="data row3 col6" >3077747</td>
#     </tr>
#     <tr>
#       <th id="T_d4025_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d4025_row4_col0" class="data row4 col0" >PKN</td>
#       <td id="T_d4025_row4_col1" class="data row4 col1" >1999-12-02 00:00:00</td>
#       <td id="T_d4025_row4_col2" class="data row4 col2" >15.82 zł</td>
#       <td id="T_d4025_row4_col3" class="data row4 col3" >16.30 zł</td>
#       <td id="T_d4025_row4_col4" class="data row4 col4" >15.74 zł</td>
#       <td id="T_d4025_row4_col5" class="data row4 col5" >15.95 zł</td>
#       <td id="T_d4025_row4_col6" class="data row4 col6" >3304014</td>
#     </tr>
#     <tr>
#       <th id="T_d4025_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d4025_row5_col0" class="data row5 col0" >PKN</td>
#       <td id="T_d4025_row5_col1" class="data row5 col1" >1999-12-03 00:00:00</td>
#       <td id="T_d4025_row5_col2" class="data row5 col2" >15.95 zł</td>
#       <td id="T_d4025_row5_col3" class="data row5 col3" >16.23 zł</td>
#       <td id="T_d4025_row5_col4" class="data row5 col4" >15.82 zł</td>
#       <td id="T_d4025_row5_col5" class="data row5 col5" >16.16 zł</td>
#       <td id="T_d4025_row5_col6" class="data row5 col6" >2357914</td>
#     </tr>
#     <tr>
#       <th id="T_d4025_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d4025_row6_col0" class="data row6 col0" >PKN</td>
#       <td id="T_d4025_row6_col1" class="data row6 col1" >1999-12-06 00:00:00</td>
#       <td id="T_d4025_row6_col2" class="data row6 col2" >16.30 zł</td>
#       <td id="T_d4025_row6_col3" class="data row6 col3" >16.85 zł</td>
#       <td id="T_d4025_row6_col4" class="data row6 col4" >16.30 zł</td>
#       <td id="T_d4025_row6_col5" class="data row6 col5" >16.78 zł</td>
#       <td id="T_d4025_row6_col6" class="data row6 col6" >3005048</td>
#     </tr>
#     <tr>
#       <th id="T_d4025_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d4025_row7_col0" class="data row7 col0" >PKN</td>
#       <td id="T_d4025_row7_col1" class="data row7 col1" >1999-12-07 00:00:00</td>
#       <td id="T_d4025_row7_col2" class="data row7 col2" >16.71 zł</td>
#       <td id="T_d4025_row7_col3" class="data row7 col3" >16.78 zł</td>
#       <td id="T_d4025_row7_col4" class="data row7 col4" >16.50 zł</td>
#       <td id="T_d4025_row7_col5" class="data row7 col5" >16.50 zł</td>
#       <td id="T_d4025_row7_col6" class="data row7 col6" >2426246</td>
#     </tr>
#     <tr>
#       <th id="T_d4025_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d4025_row8_col0" class="data row8 col0" >PKN</td>
#       <td id="T_d4025_row8_col1" class="data row8 col1" >1999-12-08 00:00:00</td>
#       <td id="T_d4025_row8_col2" class="data row8 col2" >16.50 zł</td>
#       <td id="T_d4025_row8_col3" class="data row8 col3" >16.91 zł</td>
#       <td id="T_d4025_row8_col4" class="data row8 col4" >16.50 zł</td>
#       <td id="T_d4025_row8_col5" class="data row8 col5" >16.64 zł</td>
#       <td id="T_d4025_row8_col6" class="data row8 col6" >3807338</td>
#     </tr>
#     <tr>
#       <th id="T_d4025_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d4025_row9_col0" class="data row9 col0" >PKN</td>
#       <td id="T_d4025_row9_col1" class="data row9 col1" >1999-12-09 00:00:00</td>
#       <td id="T_d4025_row9_col2" class="data row9 col2" >16.64 zł</td>
#       <td id="T_d4025_row9_col3" class="data row9 col3" >16.64 zł</td>
#       <td id="T_d4025_row9_col4" class="data row9 col4" >16.23 zł</td>
#       <td id="T_d4025_row9_col5" class="data row9 col5" >16.50 zł</td>
#       <td id="T_d4025_row9_col6" class="data row9 col6" >2513405</td>
#     </tr>
#   </tbody>
# </table>

# %%
# You can find a list of all available color maps in the matplotlib library here
# List of color maps: https://matplotlib.org/stable/users/explain/colors/colormaps.html
from matplotlib import colormaps
print(list(colormaps))

# Here's an example (like in Excel) of how to use one of them
df10.style.background_gradient(cmap='coolwarm')
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'berlin', 'managua', 'vanimo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'grey', 'gist_grey', 'gist_yerg', 'Grays', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'berlin_r', 'managua_r', 'vanimo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 'Greens_r', 'Greys_r', 'OrRd_r', 'Oranges_r', 'PRGn_r', 'PiYG_r', 'PuBu_r', 'PuBuGn_r', 'PuOr_r', 'PuRd_r', 'Purples_r', 'RdBu_r', 'RdGy_r', 'RdPu_r', 'RdYlBu_r', 'RdYlGn_r', 'Reds_r', 'Spectral_r', 'Wistia_r', 'YlGn_r', 'YlGnBu_r', 'YlOrBr_r', 'YlOrRd_r', 'afmhot_r', 'autumn_r', 'binary_r', 'bone_r', 'brg_r', 'bwr_r', 'cool_r', 'coolwarm_r', 'copper_r', 'cubehelix_r', 'flag_r', 'gist_earth_r', 'gist_gray_r', 'gist_heat_r', 'gist_ncar_r', 'gist_rainbow_r', 'gist_stern_r', 'gist_yarg_r', 'gnuplot_r', 'gnuplot2_r', 'gray_r', 'hot_r', 'hsv_r', 'jet_r', 'nipy_spectral_r', 'ocean_r', 'pink_r', 'prism_r', 'rainbow_r', 'seismic_r', 'spring_r', 'summer_r', 'terrain_r', 'winter_r', 'Accent_r', 'Dark2_r', 'Paired_r', 'Pastel1_r', 'Pastel2_r', 'Set1_r', 'Set2_r', 'Set3_r', 'tab10_r', 'tab20_r', 'tab20b_r', 'tab20c_r', 'grey_r', 'gist_grey_r', 'gist_yerg_r', 'Grays_r']
# <style type="text/css">
# #T_19cee_row0_col2 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_19cee_row0_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_19cee_row0_col4, #T_19cee_row1_col3, #T_19cee_row1_col5, #T_19cee_row2_col2, #T_19cee_row5_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_19cee_row0_col5, #T_19cee_row2_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_19cee_row0_col6, #T_19cee_row6_col5, #T_19cee_row7_col2, #T_19cee_row7_col4, #T_19cee_row8_col3, #T_19cee_row8_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_19cee_row1_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_19cee_row1_col4 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_19cee_row1_col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_19cee_row2_col3 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_19cee_row2_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_19cee_row2_col6, #T_19cee_row4_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_19cee_row3_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_19cee_row3_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_19cee_row3_col4 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_19cee_row3_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_19cee_row3_col6 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_19cee_row4_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_19cee_row4_col3 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_19cee_row4_col4 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_19cee_row4_col5 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_19cee_row5_col2 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_19cee_row5_col3 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_19cee_row5_col4 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_19cee_row5_col5 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_19cee_row6_col2 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_19cee_row6_col3 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_19cee_row6_col4 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_19cee_row6_col6 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_19cee_row7_col3 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_19cee_row7_col5, #T_19cee_row9_col5 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_19cee_row7_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_19cee_row8_col2 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_19cee_row8_col5 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_19cee_row8_col6 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_19cee_row9_col2 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_19cee_row9_col3 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_19cee_row9_col4 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_19cee_row9_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_19cee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19cee_level0_col0" class="col_heading level0 col0" >TICKER</th>
#       <th id="T_19cee_level0_col1" class="col_heading level0 col1" >DATE</th>
#       <th id="T_19cee_level0_col2" class="col_heading level0 col2" >OPEN</th>
#       <th id="T_19cee_level0_col3" class="col_heading level0 col3" >HIGH</th>
#       <th id="T_19cee_level0_col4" class="col_heading level0 col4" >LOW</th>
#       <th id="T_19cee_level0_col5" class="col_heading level0 col5" >CLOSE</th>
#       <th id="T_19cee_level0_col6" class="col_heading level0 col6" >VOL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19cee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19cee_row0_col0" class="data row0 col0" >PKN</td>
#       <td id="T_19cee_row0_col1" class="data row0 col1" >1999-11-26 00:00:00</td>
#       <td id="T_19cee_row0_col2" class="data row0 col2" >15.268000</td>
#       <td id="T_19cee_row0_col3" class="data row0 col3" >15.403000</td>
#       <td id="T_19cee_row0_col4" class="data row0 col4" >14.715000</td>
#       <td id="T_19cee_row0_col5" class="data row0 col5" >15.194000</td>
#       <td id="T_19cee_row0_col6" class="data row0 col6" >15857000</td>
#     </tr>
#     <tr>
#       <th id="T_19cee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_19cee_row1_col0" class="data row1 col0" >PKN</td>
#       <td id="T_19cee_row1_col1" class="data row1 col1" >1999-11-29 00:00:00</td>
#       <td id="T_19cee_row1_col2" class="data row1 col2" >15.124000</td>
#       <td id="T_19cee_row1_col3" class="data row1 col3" >15.194000</td>
#       <td id="T_19cee_row1_col4" class="data row1 col4" >14.852000</td>
#       <td id="T_19cee_row1_col5" class="data row1 col5" >14.923000</td>
#       <td id="T_19cee_row1_col6" class="data row1 col6" >5499196</td>
#     </tr>
#     <tr>
#       <th id="T_19cee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_19cee_row2_col0" class="data row2 col0" >PKN</td>
#       <td id="T_19cee_row2_col1" class="data row2 col1" >1999-11-30 00:00:00</td>
#       <td id="T_19cee_row2_col2" class="data row2 col2" >15.060000</td>
#       <td id="T_19cee_row2_col3" class="data row2 col3" >15.330000</td>
#       <td id="T_19cee_row2_col4" class="data row2 col4" >15.060000</td>
#       <td id="T_19cee_row2_col5" class="data row2 col5" >15.194000</td>
#       <td id="T_19cee_row2_col6" class="data row2 col6" >3287087</td>
#     </tr>
#     <tr>
#       <th id="T_19cee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_19cee_row3_col0" class="data row3 col0" >PKN</td>
#       <td id="T_19cee_row3_col1" class="data row3 col1" >1999-12-01 00:00:00</td>
#       <td id="T_19cee_row3_col2" class="data row3 col2" >15.330000</td>
#       <td id="T_19cee_row3_col3" class="data row3 col3" >15.674000</td>
#       <td id="T_19cee_row3_col4" class="data row3 col4" >15.194000</td>
#       <td id="T_19cee_row3_col5" class="data row3 col5" >15.674000</td>
#       <td id="T_19cee_row3_col6" class="data row3 col6" >3077747</td>
#     </tr>
#     <tr>
#       <th id="T_19cee_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_19cee_row4_col0" class="data row4 col0" >PKN</td>
#       <td id="T_19cee_row4_col1" class="data row4 col1" >1999-12-02 00:00:00</td>
#       <td id="T_19cee_row4_col2" class="data row4 col2" >15.818000</td>
#       <td id="T_19cee_row4_col3" class="data row4 col3" >16.297000</td>
#       <td id="T_19cee_row4_col4" class="data row4 col4" >15.745000</td>
#       <td id="T_19cee_row4_col5" class="data row4 col5" >15.954000</td>
#       <td id="T_19cee_row4_col6" class="data row4 col6" >3304014</td>
#     </tr>
#     <tr>
#       <th id="T_19cee_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_19cee_row5_col0" class="data row5 col0" >PKN</td>
#       <td id="T_19cee_row5_col1" class="data row5 col1" >1999-12-03 00:00:00</td>
#       <td id="T_19cee_row5_col2" class="data row5 col2" >15.954000</td>
#       <td id="T_19cee_row5_col3" class="data row5 col3" >16.225000</td>
#       <td id="T_19cee_row5_col4" class="data row5 col4" >15.818000</td>
#       <td id="T_19cee_row5_col5" class="data row5 col5" >16.159000</td>
#       <td id="T_19cee_row5_col6" class="data row5 col6" >2357914</td>
#     </tr>
#     <tr>
#       <th id="T_19cee_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_19cee_row6_col0" class="data row6 col0" >PKN</td>
#       <td id="T_19cee_row6_col1" class="data row6 col1" >1999-12-06 00:00:00</td>
#       <td id="T_19cee_row6_col2" class="data row6 col2" >16.297000</td>
#       <td id="T_19cee_row6_col3" class="data row6 col3" >16.847000</td>
#       <td id="T_19cee_row6_col4" class="data row6 col4" >16.297000</td>
#       <td id="T_19cee_row6_col5" class="data row6 col5" >16.776000</td>
#       <td id="T_19cee_row6_col6" class="data row6 col6" >3005048</td>
#     </tr>
#     <tr>
#       <th id="T_19cee_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_19cee_row7_col0" class="data row7 col0" >PKN</td>
#       <td id="T_19cee_row7_col1" class="data row7 col1

# %%
# we can visualize a given color palette in Jupyter Notebook
colors = plt.colormaps['viridis']
colors

# %%
# a single color is an array of normalized pixel color values (pixel_color_value / 255) for all three
# components of a RGB palette
print(colors.colors[0])

# number of all colors
len(colors.colors)
# Out:
# [0.267004, 0.004874, 0.329415]
# 256

# %% [markdown]
# ## Tasks
#
# **Task 1**
#
# Based on the radar chart examples above, write a function that can display a similar chart for the data from the FIFA22_official_data.csv dataset (located in the **data** subfolder). Requirements:
#
# * The function takes a pandas DataFrame as a vector, where the first column is the player’s name and the subsequent columns are any subset of that player’s football attributes (from Crossing to GKReflexes),
# * The function and the chart should work for a variable number of attributes and for a variable number of players,
# * Set a fixed range of attribute values between [0, 100],
# * The axis labels on the chart are the column labels excluding the player’s name,
# * Each player is represented by a different color,
# * The legend also includes the player’s name.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


def plot_player_radar(df_players):
    """First column = player name, other columns = skills between 0 and 100."""
    name_col = df_players.columns[0]
    skill_cols = list(df_players.columns[1:])
    angles = np.linspace(0, 2 * np.pi, len(skill_cols), endpoint=False).tolist()
    angles_closed = angles + angles[:1]

    fig, ax = plt.subplots(figsize=(7, 7), subplot_kw={"polar": True})
    ax.set_theta_offset(np.pi / 2)
    ax.set_theta_direction(-1)
    ax.set_ylim(0, 100)
    ax.set_thetagrids(np.degrees(angles), skill_cols)

    colors = ["C0", "C1", "C2", "C3", "C4"]
    for row_index, row in df_players.iterrows():
        vals = []
        for c in skill_cols:
            vals.append(float(row[c]))
        vals_closed = vals + vals[:1]
        color = colors[row_index % len(colors)]
        ax.plot(angles_closed, vals_closed, label=row[name_col], color=color)
        ax.fill(angles_closed, vals_closed, color=color, alpha=0.15)
    ax.legend(loc="upper right", bbox_to_anchor=(1.25, 1.05))
    plt.show()


fifa = pd.read_csv("data/FIFA22_official_data.csv")
all_cols = list(fifa.columns)
start = all_cols.index("Crossing")
end = all_cols.index("GKReflexes")
skill_cols = all_cols[start : end + 1]

demo = fifa.loc[0:1, ["Name"] + skill_cols[:8]]
plot_player_radar(demo)
# Out:
# /tmp/ipykernel_13864/1063516914.py:29: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# **Task 2**
#
# Using the [pkn.txt](./data/pkn.txt) dataset, write a script that displays an animated chart showing the closing price (the `CLOSE` column) of this security. The y-axis should show the price, and the x-axis should show the time at which each price was recorded. When the chart is first displayed, retrieve the first 20 values, and then aggregate the next reading with each animation frame. If possible, set the chart parameters so that the chart line does not lie directly at the top or right edge of the canvas.
# Also update the dates of the security’s value readings on the x-axis as the animation progresses.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

raw = pd.read_csv("data/pkn.txt")
raw.columns = [str(c).replace("<", "").replace(">", "") for c in raw.columns]
raw["when"] = pd.to_datetime(raw["DATE"].astype(str), format="%Y%m%d")

fig, ax = plt.subplots(figsize=(10, 4))
(line,) = ax.plot([], [], lw=2)
window = 20


def update(frame):
    end = min(window + frame, len(raw))
    chunk = raw.iloc[:end]
    line.set_data(chunk["when"], chunk["CLOSE"])
    ax.set_xlim(chunk["when"].iloc[0], chunk["when"].iloc[-1])
    ymin = chunk["CLOSE"].min()
    ymax = chunk["CLOSE"].max()
    ax.set_ylim(ymin * 0.98, ymax * 1.02)
    return (line,)


ani = FuncAnimation(fig, update, frames=max(1, len(raw) - window), interval=40, blit=True)
plt.show()
# Out:
# /tmp/ipykernel_13864/2149983256.py:26: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# **Task 3**
#
# Using the data in [pkn.txt](./data/pkn.txt), plot a line chart for the closing price and add indicators to the chart as shown in the example with annotations (Example 2), which will indicate the minimum and maximum values.

# %%
import pandas as pd
import matplotlib.pyplot as plt

raw = pd.read_csv("data/pkn.txt")
raw.columns = [str(c).replace("<", "").replace(">", "") for c in raw.columns]
raw["when"] = pd.to_datetime(raw["DATE"].astype(str), format="%Y%m%d")

plt.figure(figsize=(10, 4))
plt.plot(raw["when"], raw["CLOSE"], label="Close")

i_min = raw["CLOSE"].idxmin()
i_max = raw["CLOSE"].idxmax()
plt.annotate(
    "min",
    xy=(raw.loc[i_min, "when"], raw.loc[i_min, "CLOSE"]),
    xytext=(0, 15),
    textcoords="offset points",
    ha="center",
)
plt.annotate(
    "max",
    xy=(raw.loc[i_max, "when"], raw.loc[i_max, "CLOSE"]),
    xytext=(0, -20),
    textcoords="offset points",
    ha="center",
)
plt.xlabel("Date")
plt.ylabel("Close")
plt.legend()
plt.margins(0.05)
plt.show()
# Out:
# /tmp/ipykernel_13864/3155101056.py:31: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# **Task 4**
#
# Using the data from [pkn.txt](./data/pkn.txt), group the data by year and month, find the minimum and maximum values for the `CLOSE` column, and then, using the data formatting example from point 4, highlight the minimum and maximum values in this column with different styles (using the `highlight_min` and `highlight_max` functions, respectively).

# %%
import pandas as pd

raw = pd.read_csv("data/pkn.txt")
raw.columns = [str(c).replace("<", "").replace(">", "") for c in raw.columns]
raw["when"] = pd.to_datetime(raw["DATE"].astype(str), format="%Y%m%d")
raw["Year"] = raw["when"].dt.year
raw["Month"] = raw["when"].dt.month

summary = raw.groupby(["Year", "Month"])["CLOSE"].agg(["min", "max"]).reset_index()
styled = summary.style.highlight_min(subset=["min"], color="lightgreen").highlight_max(
    subset=["max"], color="salmon"
)
from IPython.display import display

display(styled)
# Out:
# <style type="text/css">
# #T_6266a_row22_col2 {
#   background-color: lightgreen;
# }
# #T_6266a_row215_col3 {
#   background-color: salmon;
# }
# </style>
# <table id="T_6266a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6266a_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_6266a_level0_col1" class="col_heading level0 col1" >Month</th>
#       <th id="T_6266a_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_6266a_level0_col3" class="col_heading level0 col3" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6266a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6266a_row0_col0" class="data row0 col0" >1999</td>
#       <td id="T_6266a_row0_col1" class="data row0 col1" >11</td>
#       <td id="T_6266a_row0_col2" class="data row0 col2" >14.923000</td>
#       <td id="T_6266a_row0_col3" class="data row0 col3" >15.194000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6266a_row1_col0" class="data row1 col0" >1999</td>
#       <td id="T_6266a_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_6266a_row1_col2" class="data row1 col2" >15.674000</td>
#       <td id="T_6266a_row1_col3" class="data row1 col3" >17.950000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6266a_row2_col0" class="data row2 col0" >2000</td>
#       <td id="T_6266a_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_6266a_row2_col2" class="data row2 col2" >17.256000</td>
#       <td id="T_6266a_row2_col3" class="data row2 col3" >18.908000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6266a_row3_col0" class="data row3 col0" >2000</td>
#       <td id="T_6266a_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_6266a_row3_col2" class="data row3 col2" >15.330000</td>
#       <td id="T_6266a_row3_col3" class="data row3 col3" >17.806000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6266a_row4_col0" class="data row4 col0" >2000</td>
#       <td id="T_6266a_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_6266a_row4_col2" class="data row4 col2" >15.268000</td>
#       <td id="T_6266a_row4_col3" class="data row4 col3" >16.711000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6266a_row5_col0" class="data row5 col0" >2000</td>
#       <td id="T_6266a_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_6266a_row5_col2" class="data row5 col2" >15.124000</td>
#       <td id="T_6266a_row5_col3" class="data row5 col3" >16.088000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6266a_row6_col0" class="data row6 col0" >2000</td>
#       <td id="T_6266a_row6_col1" class="data row6 col1" >5</td>
#       <td id="T_6266a_row6_col2" class="data row6 col2" >13.957000</td>
#       <td id="T_6266a_row6_col3" class="data row6 col3" >15.539000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6266a_row7_col0" class="data row7 col0" >2000</td>
#       <td id="T_6266a_row7_col1" class="data row7 col1" >6</td>
#       <td id="T_6266a_row7_col2" class="data row7 col2" >14.230000</td>
#       <td id="T_6266a_row7_col3" class="data row7 col3" >15.403000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6266a_row8_col0" class="data row8 col0" >2000</td>
#       <td id="T_6266a_row8_col1" class="data row8 col1" >7</td>
#       <td id="T_6266a_row8_col2" class="data row8 col2" >13.886000</td>
#       <td id="T_6266a_row8_col3" class="data row8 col3" >15.060000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6266a_row9_col0" class="data row9 col0" >2000</td>
#       <td id="T_6266a_row9_col1" class="data row9 col1" >8</td>
#       <td id="T_6266a_row9_col2" class="data row9 col2" >13.478000</td>
#       <td id="T_6266a_row9_col3" class="data row9 col3" >14.371000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6266a_row10_col0" class="data row10 col0" >2000</td>
#       <td id="T_6266a_row10_col1" class="data row10 col1" >9</td>
#       <td id="T_6266a_row10_col2" class="data row10 col2" >12.104000</td>
#       <td id="T_6266a_row10_col3" class="data row10 col3" >14.230000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6266a_row11_col0" class="data row11 col0" >2000</td>
#       <td id="T_6266a_row11_col1" class="data row11 col1" >10</td>
#       <td id="T_6266a_row11_col2" class="data row11 col2" >10.759000</td>
#       <td id="T_6266a_row11_col3" class="data row11 col3" >12.511000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6266a_row12_col0" class="data row12 col0" >2000</td>
#       <td id="T_6266a_row12_col1" class="data row12 col1" >11</td>
#       <td id="T_6266a_row12_col2" class="data row12 col2" >12.720000</td>
#       <td id="T_6266a_row12_col3" class="data row12 col3" >14.093000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6266a_row13_col0" class="data row13 col0" >2000</td>
#       <td id="T_6266a_row13_col1" class="data row13 col1" >12</td>
#       <td id="T_6266a_row13_col2" class="data row13 col2" >13.820000</td>
#       <td id="T_6266a_row13_col3" class="data row13 col3" >15.466000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6266a_row14_col0" class="data row14 col0" >2001</td>
#       <td id="T_6266a_row14_col1" class="data row14 col1" >1</td>
#       <td id="T_6266a_row14_col2" class="data row14 col2" >14.230000</td>
#       <td id="T_6266a_row14_col3" class="data row14 col3" >15.539000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6266a_row15_col0" class="data row15 col0" >2001</td>
#       <td id="T_6266a_row15_col1" class="data row15 col1" >2</td>
#       <td id="T_6266a_row15_col2" class="data row15 col2" >12.241000</td>
#       <td id="T_6266a_row15_col3" class="data row15 col3" >15.060000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6266a_row16_col0" class="data row16 col0" >2001</td>
#       <td id="T_6266a_row16_col1" class="data row16 col1" >3</td>
#       <td id="T_6266a_row16_col2" class="data row16 col2" >11.754000</td>
#       <td id="T_6266a_row16_col3" class="data row16 col3" >12.855000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6266a_row17_col0" class="data row17 col0" >2001</td>
#       <td id="T_6266a_row17_col1" class="data row17 col1" >4</td>
#       <td id="T_6266a_row17_col2" class="data row17 col2" >11.826000</td>
#       <td id="T_6266a_row17_col3" class="data row17 col3" >13.686000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6266a_row18_col0" class="data row18 col0" >2001</td>
#       <td id="T_6266a_row18_col1" class="data row18 col1" >5</td>
#       <td id="T_6266a_row18_col2" class="data row18 col2" >12.305000</td>
#       <td id="T_6266a_row18_col3" class="data row18 col3" >13.615000</td>
#     </tr>
#     <tr>
#       <th id="T_6266a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_6266a_row19_col0" class="data row19 col0" >2001</td>
#       <td id="T_6266a_row19_col1" class="data row19 col1" >6</td>
#       <td id="T_6266a_row19_col2" class="data row19 col2" >12.104000</td>
#       <td id="T_6266a

# %% [markdown]
# Exemplary plot for task 1 could look like this:
#
# ![radar_plot_ex1.png](radar_plot_ex1.png)
